# %%
# line contionos 
a=1+4+5+6+7+ \
6+7
print(a)
# Out:
# 36

# %%
a=6
b='yousaf'
c=3.5
d=[4,3,4]
e={3,4,5}

print(type(a))
print(type(b))
print(type(c))
print(type(d))
print(type(e))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>
# <class 'list'>
# <class 'set'>

# %%
# case sencensative
name='Muhammad'
Name='Yousaf'
print(name,"-",Name)
print(Name)
# Out:
# Muhammad - Yousaf
# Yousaf
