# %% [markdown]
# Now Here we practice a basic data types in python like int float str and bollean etc

# %%
# interger to store integer type value
age=23
print(age)
# Out:
# 23

# %%
# float 
height=5.11
print(height)
# Out:
# 5.11

# %%
# string : str
name='Muhammad Yousaf'
print(name)
# Out:
# Muhammad Yousaf

# %%
# Bolean : means true or false
password=True
print(type(password))
# Out:
# <class 'bool'>

# %%
num_str = "50"     # string
num = int(num_str) # convert to integer
print(num + 10)
# Output: 60
# Out:
# 60

# %%
# name = "yousaf"
# age = 21
# Age = str(age)   # converting int to string
# print(name+Age)

# %%
name=None
print(type(name))
# Out:
# <class 'NoneType'>
