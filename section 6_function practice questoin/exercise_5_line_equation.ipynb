# %% [markdown]
# # Exercise 5: Line Equation y = mx + c

# %%
def line_eq(m, x, c):
    return m*x + c

m = float(input('Enter slope (m): '))
x = float(input('Enter x: '))
c = float(input('Enter intercept (c): '))
print('y =', line_eq(m,x,c))
# Out:
# y = 50.0
