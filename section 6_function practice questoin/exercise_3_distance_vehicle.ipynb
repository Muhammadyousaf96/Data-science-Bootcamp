# %% [markdown]
# # Exercise 3: Distance Covered by Vehicle

# %%
def distance(speed, time):
    return speed * time

s = float(input('Speed (km/hr): '))
t = float(input('Time (hr): '))
print('Distance:', distance(s,t))
# Out:
# Distance: 42.0
