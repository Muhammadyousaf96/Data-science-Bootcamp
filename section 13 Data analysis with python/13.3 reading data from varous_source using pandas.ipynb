# %% [markdown]
# Reading data from various sources by using pandas
# ===
# Pandas is a powerful library in Python that provides data structures and data analysis tools. It allows you to read data from various sources, such as CSV files, Excel files, SQL databases, and more. Here are some common ways to read data using pandas:

# %%
import pandas as pd 
from io import StringIO

data='{"em_name:"yousaf",job:"data scientist""}'

# df=pd.read_json(StringIO(data))

# df.to_json()

# %%
# df=pd.read_csv("https://www.ibm.com/think/topics/data")

# df

# %%
# pip install lxml

# %%
url="file:///D:/Data%20science%20bootcamp/Python/section%2013%20Data%20analysis%20with%20python/pandas_learning_guide.html"

df=pd.read_html(url)

df
# Out:
# [   index ↓    Name  Math  Physics  CS Grade
#  0        0     Ali    85       76  95     A
#  1        1    Sara    72       85  90     B
#  2        2   Hamza    55       60  70     C
#  3        3  Ayesha    95       92  98     A,
#                    Task                Pandas Tool  \
#  0             Load CSV              pd.read_csv()
#  1       Quick overview  df.info() + df.describe()
#  2     Select rows/cols           .loc[] / .iloc[]
#  3          Filter rows    Boolean mask / .query()
#  4         Handle nulls      .fillna() / .dropna()
#  5   Aggregate by group           .groupby().agg()
#  6          Add columns                  .assign()
#  7       Combine tables                 pd.merge()
#  8         Stack tables                pd.concat()
#  9        Time grouping                .resample()
#  10        Custom logic             .apply(axis=1)
#  11         Pivot table             .pivot_table()
#
#                                               Notes
# ...
