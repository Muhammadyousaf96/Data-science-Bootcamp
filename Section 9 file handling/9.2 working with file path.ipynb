# %% [markdown]
# Here we practice and  working with file path
# ===

# %%
# create a new directory
import os
new_directory="package"
os.makedirs(new_directory)
print(f"Directory '{new_directory}created")
# Out:
# Directory 'packagecreated

# %%
# listing files and directories
items=os.listdir(".")
print(items)
# Out:
# ['9.1 file_operation.ipynb', '9.2 working with file path.ipynb', 'example.txt', 'filehandlingsolution.ipynb', 'package']

# %%
# joinging paaths
dir_name="folder"
file_name="file.text"
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.text

# %%
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# d:\Data science bootcamp\Python\Section 9 file handling\folder\file.text

# %%
path="example1.txt"
if os.path.exists(path):
    print(f"The file {path} exists")
else:
    print(f"The file {path} does not exist")
# Out:
# The file example1.txt does not exist

# %%
# checking if a path is a file or directory
import os
path="package"
if os.path.isfile(path):
    print(f"path {path}is a file")
elif os.path.isdir(path):
    print(f"path {path}is a directory")
else:
    print(f"path {path}does not exist")
# Out:
# path packageis a directory

# %%
#getting the absolute path
import os 
relative_path="example.txt"
absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# d:\Data science bootcamp\Python\Section 9 file handling\example.txt
