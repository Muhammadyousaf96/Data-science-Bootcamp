# %% [markdown]
# Exception Handling in python
# ===

# %%
# exception handling is a way to handle errors that may occur in a program. 
# It allows you to write code that can gracefully handle errors without crashing the program.
# The basic syntax for exception handling in Python is as follows:
# there are four main keywords used in exception handling: try, except, else, and finally.
# there are a exception types like dividde by zero error, index error, key error, value error, type error, etc.

# %%
# try except block , nameError
# try:
    
    # result=2/0

# except: 
    # print("Division by zero not allowed")    
    # print(result)

# %%
try:
    number=int(input("Enter a number: "))
    result=10/number
    print(result)
except ZeroDivisionError:
    print("Division by zero not allowed")
# Out:
# Division by zero not allowed

# %%
try :
    num=23/0
except ZeroDivisionError as e:
    print(e)
# Out:
# division by zero

# %%
# Multiple exception catching
try: 
    a=b
    num=32/0
except NameError as name_error:
    print(name_error)
except ZeroDivisionError as zero_division_error:
    print(zero_division_error)
# Out:
# name 'b' is not defined

# %%
try:
    a=b
    result=2/0
except Exception as e:
    print(e)
# Out:
# name 'b' is not defined

# %%
try:
    num=int(input("Enter a number:"))
    result=10/num
except NameError as name_error:
    print(name_error)
except ZeroDivisionError as zero_division_error:
    print(zero_division_error)        
except Exception as e:
    print(e)
# Out:
# invalid literal for int() with base 10: 'hhh'

# %% [markdown]
# Try , Except,else block
# ---

# %%
# now here we practice a try except and else block
# when there was a exception then except block will execute and else block will not execute 
# when there was no exception then else block will execute and except block will not execute

try:
    num=int(input("Enter a number:"))
    result=10/num   
except Exception as e:
    print(e)  
    
else:
    print(F"The result is {result}")
# Out:
# division by zero

# %%
# Try except and finally block
# finally block will execute no matter what, whether there was an exception or not  
try:
    num=int(input("Enter a number:"))
    result=10/num   
except Exception as e:
    print(e)
else:
    print(F"The result is {result}")
finally:
    print("this Execution is completed")
# Out:
# The result is 0.5
# this Execution is completed

# %% [markdown]
# File Handling and exception handling
# ---

# %%
try:
    file=open("test.txt","r")
    content=file.read()
except FileNotFoundError:
    print("file  not Found Error")
finally:
    if 'file' in locals():
        file.close()

# %%
try:
    file=open("test.txt","w")
    content=file.write("This is a test file.")
except Exception as e:
    print(e)

# %% [markdown]
# Assignment Questions practice
# ====

# %%
# Assignment #1
# Write a function that takes two integers as input and returns their division. Use try, except, 
# and finally blocks to handle division by zero and print an appropriate message.

def divide(a,b):
    try:
        result=a/b
    except ZeroDivisionError as e:
        print(f"error {e}")   
        result=None
    finally:
        print("execution complete")
    return result
print(divide(12,4))
# Out:
# execution complete
# 3.0

# %% [markdown]
# ### Assignment 2: File Reading with Exception Handling

# %% [markdown]
# Write a function that reads the contents of a file named `data.txt`. Use try, except, and finally blocks to handle file not found errors and ensure the file is properly closed.

# %%
def read_file(filename):
    try:
        file=open(filename,'r')
        contents=file.read()
        return content
    except FileNotFoundError as e:
        print(f"file not found : {e}")
    finally:
        print("execution Completed")    
print(read_file('test.txt') )
# Out:
# execution Completed
# 20

# %% [markdown]
# ### Assignment 3: Handling Multiple Exceptions

# %% [markdown]
# Write a function that takes a list of integers and returns their sum. Use try, except, and finally blocks to handle TypeError if a non-integer value is encountered and print an appropriate message.

# %%
def sum_list(lst):
    total=0
    try:
        for item in lst:
            total+=item
    except TypeError as e:
        print(f"error : {e}")    
        total=None
    finally:
        print("execution completed")
    return total    
print(sum_list([1,2,3,4,5]))
# Out:
# execution completed
# 15

# %% [markdown]
# ### Assignment 4: Exception Handling in User Input

# %% [markdown]
# Write a function that prompts the user to enter an integer. Use try, except, and finally blocks to handle ValueError if the user enters a non-integer value and print an appropriate message.

# %%
def get_integer():
    try:
        value = int(input("Enter an integer: "))
    except ValueError as e:
        print(f"Error: {e}")
        value = None
    finally:
        print("Execution complete.")
    return value

# Test
print(get_integer())
# Out:
# Error: invalid literal for int() with base 10: 'e'
# Execution complete.
# None

# %% [markdown]
# ### Assignment 5: Exception Handling in Dictionary Access

# %% [markdown]
# Write a function that takes a dictionary and a key as input and returns the value associated with the key. Use try, except, and finally blocks to handle KeyError if the key is not found in the dictionary and print an appropriate message.

# %%
def get_dictionay(d,key):
    try:
        value=d[key]
    except KeyError as e:
        print(f"error : {e}")
        value=None
    finally:
        print("execution complete")
    return value

d = {'a': 1, 'b': 2, 'c': 3}
print(get_dictionay(d, 'b'))  # 2
print(get_dictionay(d, 'x'))
# Out:
# execution complete
# 2
# error : 'x'
# execution complete
# None

# %% [markdown]
# ### Assignment 6: Nested Exception Handling

# %% [markdown]
# Write a function that performs nested exception handling. It should first attempt to convert a string to an integer, and then attempt to divide by that integer. Use nested try, except, and finally blocks to handle ValueError and ZeroDivisionError and print appropriate messages.

# %%
def nested_exception_handling(s):
    try:
        try:
            num=int(s)
        except ValueError as e:
            print(f"conversion error: {e}") 
            num=None
        finally:
            print("Conversion attempt complete")
        if num is not None:
            try:
                result=10/num
            except ZeroDivisionError as e:
                print(f"division error: {e}")
                result=None
            finally:
                print("Division attempt complete")                    
            return result
    finally:
        print("Execution complete")
        
print(nested_exception_handling('i'))
# Out:
# conversion error: invalid literal for int() with base 10: 'i'
# Conversion attempt complete
# Execution complete
# None

# %% [markdown]
# ### Assignment 7: Exception Handling in List Operations

# %% [markdown]
# Write a function that takes a list and an index as input and returns the element at the given index. Use try, except, and finally blocks to handle IndexError if the index is out of range and print an appropriate message.

# %%
def get_list_element(lst,index):
    try:
        element=lst[index]
    except IndexError  as e:
        print(f"Index error: {e}")    
        element=None
    finally:
        print("execution complete")
    return element
print(get_list_element([1,2,3,4,5],0))  
print(get_list_element([1,2,3,4,5],2))
# Out:
# execution complete
# 1
# execution complete
# 3

# %% [markdown]
# ### Assignment 8: Exception Handling in Network Operations

# %% [markdown]
# Write a function that attempts to open a URL and read its contents. Use try, except, and finally blocks to handle network-related errors and print an appropriate message.

# %%
import requests

def read_url(url):
    try:
        response=requests.get(url)
        response.raise_for_status()  # Check for HTTP errors
        return response.text
    except requests.RequestException as e:    
        print(f"Error fetching URL: {e}")
    finally:
        print("Execution complete")
# print(read_url("https://www.google.com"))        
print(read_url('https://jsonplaceholder.typicode.com/posts/1'))
# Out:
# Execution complete
# {
#   "userId": 1,
#   "id": 1,
#   "title": "sunt aut facere repellat provident occaecati excepturi optio reprehenderit",
#   "body": "quia et suscipit\nsuscipit recusandae consequuntur expedita et cum\nreprehenderit molestiae ut ut quas totam\nnostrum rerum est autem sunt rem eveniet architecto"
# }

# %% [markdown]
# ### Assignment 9: Exception Handling in JSON Parsing

# %% [markdown]
# Write a function that attempts to parse a JSON string. Use try, except, and finally blocks to handle JSONDecodeError if the string is not a valid JSON and print an appropriate message.

# %%
import json

def parse_json(json_string):
    try:
        data=json.loads(json_string)
        return data
    except json.JSONDecodeError as e:
        print(f"JSON decode error: {e}")
        return None
    finally:
        print("Execution complete")
        
print(parse_json('{"name":"John", "age":30}'))     
# print(parse_json('{"name1":"John", "age":30,"name":"Muhammad"}'))
# print(parse_json(" hhg"))
# Out:
# Execution complete
# {'name': 'John', 'age': 30}

# %% [markdown]
# ### Assignment 10: Custom Exception Handling

# %% [markdown]
# Define a custom exception named `NegativeNumberError`. Write a function that raises this exception if a negative number is encountered in a list. Use try, except, and finally blocks to handle the custom exception and print an appropriate message.

# %%
class NegativeNumberError(Exception):
    pass

def check_for_negative(lst):
    try:
        for num in lst:
            if num<0:
                raise NegativeNumberError(f"Negative number found: {num}")
    except NegativeNumberError as e:
        print(f"Error: {e}")
    finally:
        print("Execution complete")
# print(check_for_negative([1,2,3,-4,5]))            
print(check_for_negative([1,2,3,4,5]))
# Out:
# Execution complete
# None

# %% [markdown]
# ### Assignment 11: Exception Handling in Function Calls

# %% [markdown]
# Write a function that calls another function which may raise an exception. Use try, except, and finally blocks to handle the exception and print an appropriate message.

# %%
def risky_function():
    raise ValueError("This is a risky function that always raises an error.")

def safe_function():
    try:
        risky_function()
    except ValueError as e:
        print(f"Caught an error: {e}")
    finally:
        print("Execution complete")
               
print(safe_function())    
# print(rIsky_function())
# Out:
# Caught an error: This is a risky function that always raises an error.
# Execution complete
# None

# %% [markdown]
# ### Assignment 12: Exception Handling in Class Methods

# %% [markdown]
# Define a class with a method that performs a division operation. Use try, except, and finally blocks within the method to handle division by zero and print an appropriate message.
