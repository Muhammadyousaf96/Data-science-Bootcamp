# %% [markdown]
# here we practice that how to import module in python and how to creating own custom module in python

# %%
from package.maths import*
print(addition(4,5))
print(subtraction(4,8))

from package import mult
mult.multiply(4,0)
# Out:
# 9
# -4
# 0

# %%
from package.maths import addition
from package.maths import subtraction
addition(2,5)
subtraction(4,5)
# Out:
# -1

# %%
from package.mult import  multiply
multiply(3,6)
# Out:
# 18

# %% [markdown]
# subpackage

# %%
from package.subpackage.div import division
division(4,5)
# Out:
# 0.8

# %%
from package.subpackage import div
div.division(4,3)
# Out:
# 1.3333333333333333

# %%
import numpy as np
np.array([3,4,5])
# Out:
# array([3, 4, 5])
